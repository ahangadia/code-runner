# %%
import turtle
import math
import random
screen = turtle.Screen()
screen.bgcolor("black")
t = turtle.Turtle()
t.speed(0)
t.hideturtle()
t.pensize(1)
colors = [ "red", "blue", "lime", "yellow", "cyan", "magenta", "orange", "pink"]
for i in range(120):
    t.penup()
    t.goto(0, 40)
    angle = i * (math.pi * 2) / 120
    x = 16 * (math.sin(angle) ** 3) * 15
    y = (13 * math.cos(angle) - 5 * math.cos(2 * angle) - 2 * math.cos(3 * angle) - math.cos(4 * angle)) * 15
    c = random.choice(colors)
    t.color(c)
    t.pendown()
    t.goto(x, y)
    for _ in range(8):
        t.forward(6)
        t.backward(6)
        t.right(45)

turtle.done()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[2], line 23
#      19     t.pendown()
#      20     t.goto(x, y)
#      21     for _ in range(8):
#      22         t.forward(6)
# ---> 23         t.backward(6)
#      24         t.right(45)
#      25
#      26 turtle.done()
#
# File ~\anaconda3\Lib\turtle.py:1725, in TNavigator.back(self, distance)
#    1707 def back(self, distance):
#    1708     """Move the turtle backward by distance.
#    1709
#    1710     Aliases: back | backward | bk
#    (...)   1723     (-30.00,0.00)
#    1724     """
# -> 1725     self._go(-distance)
#
# File ~\anaconda3\Lib\turtle.py:1666, in TNavigator._go(self, distance)
#    1664 """move turtle forward by specified distance"""
#    1665 ende = self._position + self._orient * distance
# -> 1666 self._goto(ende)
#
# File ~\anaconda3\Lib\turtle.py:3276, in RawTurtle._goto(self, end)
#    3268 go_modes = ( self._drawing,
#    3269              self._pencolor,
#    3270              self._pensize,
#    3271              isinstance(self._fillpath, list))
#    3272 screen = self.screen
#    3273 undo_entry = ("go", self._position, end, go_modes,
#    3274               (self.currentLineItem,
#    3275               self.currentLine[:],
# -> 3276               screen._pointlist(self.currentLineItem),
#    3277               self.items[:])
#    3278               )
#    3279 if self.undobuffer:
#    3280     self.undobuffer.push(undo_entry)
#
# File ~\anaconda3\Lib\turtle.py:747, in TurtleScreenBase._pointlist(self, item)
#     739 def _pointlist(self, item):
#     740     """returns list of coordinate-pairs of points of item
#     741     Example (for insiders):
#     742     >>> from turtle import *
#    (...)    745     (9.9999999999999982, 0.0)]
#     746     >>> """
# --> 747     cl = self.cv.coords(item)
#     748     pl = [(cl[i], -cl[i+1]) for i in range(0, len(cl), 2)]
#     749     return  pl
#
# File <string>:1, in coords(self, *args, **kw)
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\anaconda3\Lib\tkinter\__init__.py:2997, in Canvas.coords(self, *args)
#    2993 """Return a list of coordinates for the item given in ARGS."""
#    2994 args = _flatten(args)
#    2995 return [self.tk.getdouble(x) for x in
#    2996                    self.tk.splitlist(
# -> 2997            self.tk.call((self._w, 'coords') + args))]
#
# TclError: invalid command name ".!canvas"
